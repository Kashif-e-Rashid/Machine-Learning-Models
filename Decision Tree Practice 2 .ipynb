# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Admin/Desktop/Buys or not.csv')
df
# Out:
#    Age  Income Student Credit_Rating Buys_Computer
# 0   25     Low      No          Fair            No
# 1   45    High      No     Excellent           Yes
# 2   35  Medium     Yes          Fair           Yes
# 3   33  Medium     Yes          Fair           Yes
# 4   52    High      No     Excellent            No
# 5   23     Low     Yes          Fair           Yes
# 6   40  Medium      No     Excellent            No
# 7   60    High      No          Fair           Yes
# 8   48  Medium     Yes     Excellent           Yes
# 9   29     Low     Yes          Fair           Yes

# %%
encoder = LabelEncoder()
for column in df.columns:
    df[column] = encoder.fit_transform(df[column])

# %%
x = df.drop('Buys_Computer', axis=1 )
y = df['Buys_Computer']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(10, 6))
plot_tree(model, feature_names= x.columns, class_names=['No', 'Yes'], filled=True)
plt.title('Decision Tree')
plt.show()
